# %%
import re
num=("4532678,8765438765")
new=re.findall("\d{10}",num) 
print(new)
# Out:
# ['8765438765']

# %%
import re
text="sam@gmail.com,@gmail.com,arun@anudip.org"
new=re.findall("\w+@\w+.\w+",text)
print(new)
# Out:
# ['sam@gmail.com', 'arun@anudip.org']

# %%
import re
text="sales:500,profit:100"
new=re.findall("\d+",text)
print(new)
# Out:
# ['500', '100']

# %%
import re
text="AF0986746"
data=re.findall('\d+',text)
print(data)
# Out:
# ['0986746']

# %%
import re
text="AF0986746"
data=re.findall('[A-Z]',text)
print(data)
# Out:
# ['A', 'F']

# %%
import re
text="sql Power BI"
new=re.sub("Power BI","Power- BI",text)
print(new)
print(text)
# Out:
# sql Power- BI
# sql Power BI

# %%
import re
text="A paradigm is a typical example, a model, or a broad framework of assumptions and theories that shape how we perceive reality and approach problem-solving. It acts as a mental lens through which a person, society, or scientific community understands a"
res=re.search("mental",text)
print(res)
# Out:
# <re.Match object; span=(169, 175), match='mental'>
