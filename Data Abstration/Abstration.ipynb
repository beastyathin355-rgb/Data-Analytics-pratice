# %%
abc import from ABC 
class employee :
    def work (self) :
        pass

class HR (employee) :
    def work (self) :
        return"hiring"
    
class developer (employee) :
    def work (self) :
        return"develop"
    
D = developer 
 print(D.work())
# Out:
#   Cell In[17], line 14
#     print(D.work())
#     ^
# IndentationError: unexpected indent
