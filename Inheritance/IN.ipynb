# %%
class Employee:
    def work(self):
        print("working")

# %%
class Manager(Employee):
    pass


m=Manager()
m.work()
# Out:
# working

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary

Employee1=Employee('ram',50000)
Employee1.salary=80000
print(Employee1.salary)
# Out:
# 80000

# %%
class Employee:
    def __init__(self,name):
        self.name=name
        self.salary=50000

Employee1=Employee('ram')
Employee1.salary=80000
print(Employee1.salary)
# Out:
# 80000

# %%
class Employee:
    def __init__(self,name):
        self.name=name
        self.__salary=50000

Employee1=Employee('ram')
Employee1.salary=80000
print(Employee1.__salary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 8
#       6 Employee1=Employee('ram')
#       7 Employee1.salary=80000
# ----> 8 print(Employee1.__salary)
#
# AttributeError: 'Employee' object has no attribute '__salary'

# %%
class student:
    def __init__(self,name,mark):
        self.name=name
        self.mark=mark

student1=student("ram","0")
print(student1.mark)
# Out:
# 0
