# %%
import numpy as np
call=np.array([5,6,7,8])
print(call)
# Out:
# [5 6 7 8]

# %%
dimensional=np.array((['jan','feb','mar'],
             [300,400,500],
             [600,700,800]))
print(dimensional.shape)
print(dimensional)
# Out:
# (3, 3)
# [['jan' 'feb' 'mar']
#  ['300' '400' '500']
#  ['600' '700' '800']]

# %%
mc=np.array((['jan','feb','mar'],
             [300,400,500],
             [600,700,800]))
mc[2][2]
# Out:
# np.str_('800')

# %%
mc=np.array((['jan','feb','mar'],
             [300,400,500],
             [600,700,800]))
mc[0:,1]
# Out:
# np.str_('feb')

# %%
sr = np.array([3.6,4,2,6,1,3])
sr[sr>3]
# Out:
# array([3.6, 4. , 6. ])

# %%
sr = np.array([3,6,4,2,6,1,3])
sr[(sr>2) & (sr<4)]
# Out:
# array([3, 3])

# %%
dimensional=np.array(([300,400,500],
             [600,700,800]))
print(np.sum(dimensional))
# Out:
# 3300

# %%
dimensional=np.array((['jan','feb','mar'],
             [300,400,500],
             [600,700,800]))
print(np.sum (dimensional[1:].astype('int')))
# Out:
# 3300

# %%
North = np.array([5,60,90])
South = np.array([3,20,5])
print(np.concatenate((North,South)))
# Out:
# [ 5 60 90  3 20  5]

# %%
np.add(dimensional[1:,].astype('int'),dimensional[2:,].astype('int'))
# Out:
# array([[ 900, 1100, 1300],
#        [1200, 1400, 1600]])
